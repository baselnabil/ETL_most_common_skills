# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder \
        .appName("ETL")\
        .getOrCreate()
# Out:
# 24/08/23 16:21:33 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %%
df = spark.read.csv('../../data/raw/data1.csv')
# Out:
#                        id           site  \
# 0           1009411580728      glassdoor
# 1        2bb17ebab6fe2ff1         indeed
# 2              4002140721       linkedin
# 3  e9Ocfk-AZdrNccwkacC7bA  zip_recruiter
#
#                                              job_url  \
# 0  https://www.glassdoor.com/job-listing/j?jl=100...
# 1  https://www.indeed.com/viewjob?jk=2bb17ebab6fe...
# 2      https://www.linkedin.com/jobs/view/4002140721
# 3  https://www.ziprecruiter.com/jobs//j?lvk=e9Ocf...
#
#                        job_url_direct  \
# 0                                 NaN
# 1  https://ameripros.net/careers.html
# 2                                 NaN
# 3                                 NaN
#
#                                      title                 company  \
# 0       Staff Software Engineer - Frontend                 Datadog
# 1     Computer Software Engineer - Level 2  American Professionals
# 2  Software Engineer - Early Career (2025)                   Figma
# ...

# %%
df.to_csv('./data.csv',index=False)
