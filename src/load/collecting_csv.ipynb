# %%
import pandas as pd 
import csv

# %%
# Out:
# ('1 - 3 Yrs of Exp', 14)
# ('IT/Software Development', 169)
# ('Computer Science', 118)
# ('Python', 53)
# ('Entry Level', 49)
# ('Training/Instructor', 5)
# ('Information Technology (IT)', 109)
# ('Instructor', 3)
# ('Full Stack Development', 1)
# ('2+ Yrs of Exp', 3)
# ('WWeb Scraping', 1)
# ('CI', 1)
# ('MySQL', 8)
# ('RESTful', 1)
# ('Python Django', 1)
# ('Node.js', 4)
# ('Continues Integration (CI)', 1)
# ('Continuous Delivery (CD)', 1)
# ('DevOps', 7)
# ('Github Actions', 1)
# ('0 - 3 Yrs of Exp', 3)
# ('Analysis', 20)
# ('business', 6)
# ('Computer Engineering', 18)
# ('Data Analysis', 15)
# ('Engineering', 49)
# ('Odoo', 17)
# ('ERP', 8)
# ('2 - 3 Yrs of Exp', 3)
# ('Machine Learning', 8)
# ('LLM', 1)
# ('2 - 5 Yrs of Exp', 12)
# ('Linux', 9)
# ('System Administration', 4)
# ('troubleshoot', 1)
# ('Zabbix', 2)
# ('Network', 3)
# ('Web Hosting', 1)
# ('Installation/Maintenance/Repair', 19)
# ('Functional', 1)
# ('3 - 5 Yrs of Exp', 21)
# ('Integrations', 1)
# ('CSS', 18)
# ...
