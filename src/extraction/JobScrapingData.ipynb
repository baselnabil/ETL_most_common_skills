# %%
import csv
from jobspy import scrape_jobs

# %%
jobs = scrape_jobs(
    site_name=["indeed", "linkedin", "zip_recruiter", "glassdoor"],
    search_term="software engineer",
    location="New York, NY",
    results_wanted=250,
    hours_old=168, # (only Linkedin/Indeed is hour specific, others round up to days old)
    country_indeed='USA',  # only needed for indeed / glassdoor
    
    # linkedin_fetch_description=True # get full description , direct job url , company industry and job level (seniority level) for linkedin (slower)
    # proxies=["208.195.175.46:65095", "208.195.175.45:65095", "localhost"],
    
)
print(f"Found {len(jobs)} jobs")
print(jobs.head())
jobs.to_csv("jobs.csv", quoting=csv.QUOTE_NONNUMERIC, escapechar="\\", index=False) # to_excel
# Out:
# 2024-08-21 16:57:22,897 - JobSpy - INFO - Indeed search page: 1
# 2024-08-21 16:57:22,902 - JobSpy - INFO - LinkedIn search page: 1
# 2024-08-21 16:57:23,376 - JobSpy - INFO - ZipRecruiter search page: 1
# 2024-08-21 16:57:24,279 - JobSpy - INFO - Glassdoor search page: 1
# 2024-08-21 16:57:24,479 - JobSpy - INFO - Indeed search page: 2
# 2024-08-21 16:57:26,444 - JobSpy - INFO - Indeed search page: 3
# 2024-08-21 16:57:27,268 - JobSpy - INFO - LinkedIn search page: 2
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\markdownify\__init__.py:96: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(html, 'html.parser')
# 2024-08-21 16:57:27,293 - JobSpy - INFO - Indeed finished scraping
# 2024-08-21 16:57:27,293 - JobSpy - INFO - Glassdoor search page: 2
# 2024-08-21 16:57:30,853 - JobSpy - INFO - Glassdoor search page: 3
# 2024-08-21 16:57:31,181 - JobSpy - INFO - ZipRecruiter search page: 2
# 2024-08-21 16:57:33,793 - JobSpy - INFO - LinkedIn search page: 3
# 2024-08-21 16:57:34,136 - JobSpy - INFO - Glassdoor search page: 4
# 2024-08-21 16:57:37,116 - JobSpy - INFO - Glassdoor search page: 5
# 2024-08-21 16:57:38,439 - JobSpy - INFO - LinkedIn search page: 4
# 2024-08-21 16:57:38,693 - JobSpy - INFO - ZipRecruiter search page: 3
# 2024-08-21 16:57:39,492 - JobSpy - INFO - Glassdoor finished scraping
# 2024-08-21 16:57:45,245 - JobSpy - INFO - LinkedIn search page: 5
# 2024-08-21 16:57:45,537 - JobSpy - INFO - ZipRecruiter search page: 4
# 2024-08-21 16:57:52,711 - JobSpy - INFO - LinkedIn search page: 6
# 2024-08-21 16:57:53,848 - JobSpy - INFO - ZipRecruiter search page: 5
# 2024-08-21 16:57:59,095 - JobSpy - INFO - LinkedIn search page: 7
# 2024-08-21 16:58:01,005 - JobSpy - INFO - ZipRecruiter search page: 6
# 2024-08-21 16:58:06,993 - JobSpy - INFO - LinkedIn search page: 8
# 2024-08-21 16:58:08,009 - JobSpy - INFO - ZipRecruiter search page: 7
# 2024-08-21 16:58:11,050 - JobSpy - INFO - LinkedIn search page: 9
# 2024-08-21 16:58:14,861 - JobSpy - INFO - ZipRecruiter search page: 8
# 2024-08-21 16:58:16,423 - JobSpy - INFO - LinkedIn search page: 10
# 2024-08-21 16:58:21,455 - JobSpy - INFO - LinkedIn search page: 11
# 2024-08-21 16:58:21,793 - JobSpy - INFO - ZipRecruiter search page: 9
# 2024-08-21 16:58:28,582 - JobSpy - INFO - ZipRecruiter search page: 10
# 2024-08-21 16:58:29,612 - JobSpy - INFO - LinkedIn search page: 12
# 2024-08-21 16:58:35,394 - JobSpy - INFO - ZipRecruiter search page: 11
# 2024-08-21 16:58:35,404 - JobSpy - INFO - LinkedIn search page: 13
# 2024-08-21 16:58:42,344 - JobSpy - INFO - LinkedIn search page: 14
# 2024-08-21 16:58:42,393 - JobSpy - INFO - ZipRecruiter search page: 12
# 2024-08-21 16:58:48,326 - JobSpy - INFO - Linkedin finished scraping
# 2024-08-21 16:58:49,520 - JobSpy - INFO - ZipRecruiter search page: 13
# 2024-08-21 16:58:51,392 - JobSpy - INFO - ZipRecruiter finished scraping
# Found 753 jobs
#                 id       site  \
# 253  1009414252344  glassdoor
# 262  1009413056122  glassdoor
# 263  1009412924551  glassdoor
# 267  1009413161685  glassdoor
# 269  1009413056134  glassdoor
#
#                                                job_url job_url_direct  \
# 253  https://www.glassdoor.com/job-listing/j?jl=100...            NaN
# 262  https://www.glassdoor.com/job-listing/j?jl=100...            NaN
# 263  https://www.glassdoor.com/job-listing/j?jl=100...            NaN
# 267  https://www.glassdoor.com/job-listing/j?jl=100...            NaN
# 269  https://www.glassdoor.com/job-listing/j?jl=100...            NaN
#
#                                                  title        company  \
# 253  Software Engineer, Partner Engineering, Apple Pay          Apple
# 262  Full Stack Software Engineer, Customer Experience  Spring Health
# 263                         UX & Game Engine Developer   Buro Happold
# 267                           Platform DevOps Engineer           SS&C
# 269                         Senior Software Engineer I  Spring Health
#
#           location job_type date_posted salary_source  ...  \
# 253   New York, NY      NaN  2024-08-21   direct_data  ...
# 262   New York, NY      NaN  2024-08-21   direct_data  ...
# 263   New York, NY      NaN  2024-08-21   direct_data  ...
# 267  United States      NaN  2024-08-21   direct_data  ...
# 269   New York, NY      NaN  2024-08-21   direct_data  ...
#
#                                            company_url  company_url_direct  \
# 253  https://www.glassdoor.com/Overview/W-EI_IE1138...                 NaN
# 262  https://www.glassdoor.com/Overview/W-EI_IE2612...                 NaN
# 263  https://www.glassdoor.com/Overview/W-EI_IE2001...                 NaN
# 267  https://www.glassdoor.com/Overview/W-EI_IE6022...                 NaN
# 269  https://www.glassdoor.com/Overview/W-EI_IE2612...                 NaN
#
#      company_addresses company_num_employees company_revenue  \
# 253                NaN                   NaN             NaN
# 262                NaN                   NaN             NaN
# 263                NaN                   NaN             NaN
# 267                NaN                   NaN             NaN
# 269                NaN                   NaN             NaN
#
#     company_description                                     logo_photo_url  \
# 253                 NaN  https://media.glassdoor.com/sql/1138/apple-squ...
# 262                 NaN  https://media.glassdoor.com/sql/2612026/spring...
# 263                 NaN  https://media.glassdoor.com/sql/200108/burohap...
# 267                 NaN  https://media.glassdoor.com/sql/6022/ss-and-c-...
# 269                 NaN  https://media.glassdoor.com/sql/2612026/spring...
#
#     banner_photo_url ceo_name ceo_photo_url
# 253              NaN      NaN           NaN
# 262              NaN      NaN           NaN
# 263              NaN      NaN           NaN
# 267              NaN      NaN           NaN
# 269              NaN      NaN           NaN
#
# [5 rows x 31 columns]
