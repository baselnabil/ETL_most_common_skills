# %%
import csv
from jobspy import scrape_jobs

# %%
jobs = scrape_jobs(
    site_name=["indeed", "linkedin", "zip_recruiter", "glassdoor"],
    search_term="software engineer",
    location="New York, NY",
    results_wanted=250,
    hours_old=168, # (only Linkedin/Indeed is hour specific, others round up to days old)
    country_indeed='USA',  # only needed for indeed / glassdoor
    
    # linkedin_fetch_description=True # get full description , direct job url , company industry and job level (seniority level) for linkedin (slower)
    # proxies=["208.195.175.46:65095", "208.195.175.45:65095", "localhost"],
    
)
print(f"Found {len(jobs)} jobs")
print(jobs.head())
jobs.to_csv("jobs.csv", quoting=csv.QUOTE_NONNUMERIC, escapechar="\\", index=False) # to_excel
# Out:
# 2024-08-21 17:32:03,336 - JobSpy - INFO - Indeed search page: 1
# 2024-08-21 17:32:03,344 - JobSpy - INFO - LinkedIn search page: 1
# 2024-08-21 17:32:03,863 - JobSpy - INFO - ZipRecruiter search page: 1
# 2024-08-21 17:32:04,377 - JobSpy - INFO - Glassdoor search page: 1
# 2024-08-21 17:32:05,155 - JobSpy - INFO - Indeed search page: 2
# 2024-08-21 17:32:06,775 - JobSpy - INFO - Indeed search page: 3
# 2024-08-21 17:32:07,091 - JobSpy - INFO - Glassdoor search page: 2
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\markdownify\__init__.py:96: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(html, 'html.parser')
# 2024-08-21 17:32:07,906 - JobSpy - INFO - Indeed finished scraping
# 2024-08-21 17:32:09,368 - JobSpy - INFO - Glassdoor search page: 3
# 2024-08-21 17:32:11,366 - JobSpy - INFO - ZipRecruiter search page: 2
# 2024-08-21 17:32:11,491 - JobSpy - INFO - LinkedIn search page: 2
# 2024-08-21 17:32:11,865 - JobSpy - INFO - Glassdoor search page: 4
# 2024-08-21 17:32:14,166 - JobSpy - INFO - Glassdoor search page: 5
# 2024-08-21 17:32:15,386 - JobSpy - INFO - Glassdoor search page: 6
# 2024-08-21 17:32:16,059 - JobSpy - INFO - Glassdoor finished scraping
# 2024-08-21 17:32:16,934 - JobSpy - INFO - LinkedIn search page: 3
# 2024-08-21 17:32:18,602 - JobSpy - INFO - ZipRecruiter search page: 3
# 2024-08-21 17:32:21,148 - JobSpy - INFO - LinkedIn search page: 4
# 2024-08-21 17:32:25,975 - JobSpy - INFO - ZipRecruiter search page: 4
# 2024-08-21 17:32:26,365 - JobSpy - INFO - LinkedIn search page: 5
# 2024-08-21 17:32:31,939 - JobSpy - INFO - LinkedIn search page: 6
# 2024-08-21 17:32:33,182 - JobSpy - INFO - ZipRecruiter search page: 5
# 2024-08-21 17:32:38,884 - JobSpy - INFO - LinkedIn search page: 7
# 2024-08-21 17:32:40,311 - JobSpy - INFO - ZipRecruiter search page: 6
# 2024-08-21 17:32:44,882 - JobSpy - INFO - LinkedIn search page: 8
# 2024-08-21 17:32:47,242 - JobSpy - INFO - ZipRecruiter search page: 7
# 2024-08-21 17:32:50,856 - JobSpy - INFO - LinkedIn search page: 9
# 2024-08-21 17:32:54,239 - JobSpy - INFO - ZipRecruiter search page: 8
# 2024-08-21 17:32:56,844 - JobSpy - INFO - LinkedIn search page: 10
# 2024-08-21 17:33:01,219 - JobSpy - INFO - ZipRecruiter search page: 9
# 2024-08-21 17:33:03,416 - JobSpy - INFO - LinkedIn search page: 11
# 2024-08-21 17:33:07,962 - JobSpy - INFO - LinkedIn search page: 12
# 2024-08-21 17:33:08,081 - JobSpy - INFO - ZipRecruiter search page: 10
# 2024-08-21 17:33:14,982 - JobSpy - INFO - ZipRecruiter search page: 11
# 2024-08-21 17:33:15,252 - JobSpy - INFO - LinkedIn search page: 13
# 2024-08-21 17:33:20,443 - JobSpy - INFO - LinkedIn search page: 14
# 2024-08-21 17:33:21,942 - JobSpy - INFO - ZipRecruiter search page: 12
# 2024-08-21 17:33:28,175 - JobSpy - INFO - Linkedin finished scraping
# 2024-08-21 17:33:28,791 - JobSpy - INFO - ZipRecruiter search page: 13
# 2024-08-21 17:33:30,517 - JobSpy - INFO - ZipRecruiter finished scraping
# Found 762 jobs
#                 id       site  \
# 250  1009413161685  glassdoor
# 251  1009413056122  glassdoor
# 252  1009413056134  glassdoor
# 254  1009413969976  glassdoor
# 260  1009412867680  glassdoor
#
#                                                job_url job_url_direct  \
# 250  https://www.glassdoor.com/job-listing/j?jl=100...            NaN
# 251  https://www.glassdoor.com/job-listing/j?jl=100...            NaN
# 252  https://www.glassdoor.com/job-listing/j?jl=100...            NaN
# 254  https://www.glassdoor.com/job-listing/j?jl=100...            NaN
# 260  https://www.glassdoor.com/job-listing/j?jl=100...            NaN
#
#                                                  title  \
# 250                           Platform DevOps Engineer
# 251  Full Stack Software Engineer, Customer Experience
# 252                         Senior Software Engineer I
# 254                   Full Stack Developer - Associate
# 260                         Senior Engineer Full Stack
#
#                          company              location job_type date_posted  \
# 250                         SS&C         United States      NaN  2024-08-21
# 251                Spring Health          New York, NY      NaN  2024-08-21
# 252                Spring Health          New York, NY      NaN  2024-08-21
# 254                Deutsche Bank          New York, NY      NaN  2024-08-21
# 260  JetBlue Airways Corporation  Long Island City, NY      NaN  2024-08-21
#
#     salary_source  ...                                        company_url  \
# 250   direct_data  ...  https://www.glassdoor.com/Overview/W-EI_IE6022...
# 251   direct_data  ...  https://www.glassdoor.com/Overview/W-EI_IE2612...
# 252   direct_data  ...  https://www.glassdoor.com/Overview/W-EI_IE2612...
# 254   direct_data  ...  https://www.glassdoor.com/Overview/W-EI_IE3150...
# 260   direct_data  ...  https://www.glassdoor.com/Overview/W-EI_IE1138...
#
#      company_url_direct  company_addresses company_num_employees  \
# 250                 NaN                NaN                   NaN
# 251                 NaN                NaN                   NaN
# 252                 NaN                NaN                   NaN
# 254                 NaN                NaN                   NaN
# 260                 NaN                NaN                   NaN
#
#     company_revenue company_description  \
# 250             NaN                 NaN
# 251             NaN                 NaN
# 252             NaN                 NaN
# 254             NaN                 NaN
# 260             NaN                 NaN
#
#                                         logo_photo_url banner_photo_url  \
# 250  https://media.glassdoor.com/sql/6022/ss-and-c-...              NaN
# 251  https://media.glassdoor.com/sql/2612026/spring...              NaN
# 252  https://media.glassdoor.com/sql/2612026/spring...              NaN
# 254  https://media.glassdoor.com/sql/3150/deutsche-...              NaN
# 260  https://media.glassdoor.com/sql/11385/jetblue-...              NaN
#
#     ceo_name ceo_photo_url
# 250      NaN           NaN
# 251      NaN           NaN
# 252      NaN           NaN
# 254      NaN           NaN
# 260      NaN           NaN
#
# [5 rows x 31 columns]
